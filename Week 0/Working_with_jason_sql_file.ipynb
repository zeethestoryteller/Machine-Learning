# %%
import pandas as pd

# %% [markdown]
# # How to Read json file

# %%
pd.read_json('train.json')

# %% [markdown]
# # How read data from URL

# %%
pd.read_json('https://raw.githubusercontent.com/campusx-official/100-days-of-machine-learning/main/day15%20-%20working%20with%20json%20and%20sql/train.json')

# %% [markdown]
# # **How to read SQL file**

# %% [markdown]
# first we have to dowload XAMPP

# %% [markdown]
# we have to install mysql.connector

# %%
# !pip install mysql.connector
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 94.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for mysql.connector: filename=mysql_connector-2.2.9-cp312-cp312-linux_x86_64.whl size=247950 sha256=1a7bf05761335f1018104aa071f2a6842d398d0ef10a906c0d47881f2dc17e8e
#   Stored in directory: /root/.cache/pip/wheels/03/17/fa/d7604c72dd3dd6d3eb3d249abf36cc532c9a9b4354b8f1bc4f
# Successfully built mysql.connector
# ...

# %%
import mysql.connector

# %% [markdown]
# Now we have to create a connection between python and mysql database

# %%
conn = mysql.conecctor.connect(host='localhost',user='root',password='',database='world')

# %% [markdown]
# We will use this in creating pandas datafram

# %%
df = pd.read_sql_query("SELECT * FROM city WHERE CountryCode LIKE 'IND'",conn)

# %% [markdown]
# above function create pandas dataframe internally
